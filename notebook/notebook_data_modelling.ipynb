# %%
import pandas as pd
df = pd.read_csv('../data/data_20240604.csv')

# %% [markdown]
# # Data Preparation

# %%
df.head()
# Out:
#    bathrooms  bedrooms     city country currency  daysOnZillow homeStatus  \
# 0        2.0       3.0  Houston     USA      USD            -1   FOR_SALE
# 1        3.0       4.0   Humble     USA      USD            -1   FOR_SALE
# 2        2.0       5.0  Houston     USA      USD            -1   FOR_SALE
# 3        3.0       3.0  Houston     USA      USD            -1   FOR_SALE
# 4        2.0       3.0  Houston     USA      USD            -1   FOR_SALE
#
#   homeStatusForHDP       homeType  \
# 0         FOR_SALE  SINGLE_FAMILY
# 1         FOR_SALE  SINGLE_FAMILY
# 2         FOR_SALE  SINGLE_FAMILY
# 3         FOR_SALE  SINGLE_FAMILY
# 4         FOR_SALE  SINGLE_FAMILY
#
#                                               imgSrc  ...  \
# 0  https://photos.zillowstatic.com/fp/5fb6cdca67f...  ...
# 1  https://photos.zillowstatic.com/fp/b0c5e6a1a11...  ...
# 2  https://photos.zillowstatic.com/fp/e1d5c5f3526...  ...
# 3  https://photos.zillowstatic.com/fp/e0750673898...  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 656 entries, 0 to 655
# Data columns (total 48 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   bathrooms                           655 non-null    float64
#  1   bedrooms                            589 non-null    float64
#  2   city                                656 non-null    object
#  3   country                             656 non-null    object
#  4   currency                            656 non-null    object
#  5   daysOnZillow                        656 non-null    int64
#  6   homeStatus                          656 non-null    object
#  7   homeStatusForHDP                    656 non-null    object
#  8   homeType                            656 non-null    object
#  9   imgSrc                              656 non-null    object
#  10  isFeatured                          656 non-null    bool
# ...

# %% [markdown]
# too many column with null values, we will drop it

# %%
df.columns
# Out:
# Index(['bathrooms', 'bedrooms', 'city', 'country', 'currency', 'daysOnZillow',
#        'homeStatus', 'homeStatusForHDP', 'homeType', 'imgSrc', 'isFeatured',
#        'isNonOwnerOccupied', 'isPreforeclosureAuction', 'isPremierBuilder',
#        'isShowcaseListing', 'isUnmappable', 'isZillowOwned', 'latitude',
#        'livingArea', 'longitude', 'lotAreaUnit', 'lotAreaValue', 'price',
#        'priceForHDP', 'rentZestimate', 'shouldHighlight', 'state',
#        'streetAddress', 'taxAssessedValue', 'timeOnZillow', 'zestimate',
#        'zipcode', 'zpid', 'listing_sub_type.is_FSBA',
#        'listing_sub_type.is_bankOwned', 'datePriceChanged', 'priceChange',
#        'priceReduction', 'newConstructionType', 'listing_sub_type.is_newHome',
#        'unit', 'group_type', 'priceSuffix', 'providerListingID', 'openHouse',
#        'listing_sub_type.is_openHouse', 'open_house_info.open_house_showing',
#        'videoCount'],
#       dtype='object')

# %%
df.priceSuffix
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 651    NaN
# 652    NaN
# 653    NaN
# 654    NaN
# 655    NaN
# Name: priceSuffix, Length: 656, dtype: object

# %%
data = df[['bathrooms','bedrooms','daysOnZillow','homeType','isPremierBuilder',
         'livingArea','latitude', 'longitude','price','rentZestimate','zestimate',
         'priceChange']]

# %%
data.isnull().sum()
# Out:
# bathrooms             1
# bedrooms             67
# daysOnZillow          0
# homeType              0
# isPremierBuilder      0
# livingArea           68
# latitude              0
# longitude             0
# price                 0
# rentZestimate        47
# zestimate           123
# priceChange         528
# dtype: int64

# %%
data[data['zestimate'].isnull()]
# Out:
#      bathrooms  bedrooms  daysOnZillow       homeType  isPremierBuilder  \
# 7          2.0       2.0            -1   MULTI_FAMILY             False
# 11         3.0       3.0            -1  SINGLE_FAMILY             False
# 12         3.0       3.0            -1  SINGLE_FAMILY             False
# 13         3.0       4.0            -1  SINGLE_FAMILY             False
# 14         0.0       NaN            -1            LOT             False
# ..         ...       ...           ...            ...               ...
# 622        1.0       2.0             4          CONDO             False
# 630        0.0       NaN             4            LOT             False
# 642        0.0       NaN             4            LOT             False
# 644        5.0       4.0             4  SINGLE_FAMILY             False
# 655        3.0       2.0             4          CONDO             False
#
#      livingArea   latitude  longitude      price  rentZestimate  zestimate  \
# ...

# %%
data['priceChange'] = data['priceChange'].fillna(0)
# Out:
# C:\Users\user.LAPTOP-Q7VAS97O.000\AppData\Local\Temp\ipykernel_43436\123812811.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['priceChange'] = data['priceChange'].fillna(0)

# %%
data = data.dropna()

# %%
data
# Out:
#      bathrooms  bedrooms  daysOnZillow       homeType  isPremierBuilder  \
# 0          2.0       3.0            -1  SINGLE_FAMILY             False
# 1          3.0       4.0            -1  SINGLE_FAMILY             False
# 2          2.0       5.0            -1  SINGLE_FAMILY             False
# 3          3.0       3.0            -1  SINGLE_FAMILY             False
# 4          2.0       3.0            -1  SINGLE_FAMILY             False
# ..         ...       ...           ...            ...               ...
# 650        3.0       3.0             4  SINGLE_FAMILY             False
# 651        2.0       2.0             4      TOWNHOUSE             False
# 652        4.0       4.0             4  SINGLE_FAMILY             False
# 653        3.0       4.0             4  SINGLE_FAMILY             False
# 654        2.0       3.0             4  SINGLE_FAMILY             False
#
#      livingArea   latitude  longitude     price  rentZestimate  zestimate  \
# ...

# %% [markdown]
# # Modelling

# %%
# init setup
from pycaret.regression import *
reg1 = setup(data = data, target = 'price')

# compare models
best = compare_models()
# Out:
# <style type="text/css">
# #T_c9f30_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c9f30">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9f30_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c9f30_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9f30_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c9f30_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c9f30_row0_col1" class="data row0 col1" >3976</td>
#     </tr>
#     <tr>
#       <th id="T_c9f30_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c9f30_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c9f30_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_c9f30_level0_row2" class="row_heading level0 row2" >2</th>
# ...
